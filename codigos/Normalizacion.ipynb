# %% [markdown]
# # Noramlaización y Estandarización

# %% [markdown]
# Ref: https://machinelearningmastery.com/standardscaler-and-minmaxscaler-transforms-in-python/
#
# - ¿Cual es la diferencia entre standarización y normlización?
# -  La estandarización supone que sus observaciones se ajustan a una distribución gaussiana (curva de campana) con una media y una desviación estándar que se comportan bien.

# %%
# Normalización utilizando la libreria Max-Min  Scaler
from numpy import asarray
from sklearn.preprocessing import MinMaxScaler
# define data
data = asarray([[100, 0.001],
 [8, 0.05],
 [50, 0.005],
 [88, 0.07],
 [4, 0.1]])
print(data)
# define min max scaler
scaler = MinMaxScaler()
# transform data
scaled = scaler.fit_transform(data)
print(scaled)
# Out:
# [[1.0e+02 1.0e-03]
#  [8.0e+00 5.0e-02]
#  [5.0e+01 5.0e-03]
#  [8.8e+01 7.0e-02]
#  [4.0e+00 1.0e-01]]
# [[1.         0.        ]
#  [0.04166667 0.49494949]
#  [0.47916667 0.04040404]
#  [0.875      0.6969697 ]
#  [0.         1.        ]]

# %%
# Estandarización utilizando la libreria Standar Scaler
# example of a standardization
from numpy import asarray
from sklearn.preprocessing import StandardScaler
# define data
data = asarray([[100, 0.001],
 [8, 0.05],
 [50, 0.005],
 [88, 0.07],
 [4, 0.1]])
print(data)
# define standard scaler
scaler = StandardScaler()
# transform data
scaled = scaler.fit_transform(data)
print(scaled)
# Out:
# [[1.0e+02 1.0e-03]
#  [8.0e+00 5.0e-02]
#  [5.0e+01 5.0e-03]
#  [8.8e+01 7.0e-02]
#  [4.0e+00 1.0e-01]]
# [[ 1.26398112 -1.16389967]
#  [-1.06174414  0.12639634]
#  [ 0.         -1.05856939]
#  [ 0.96062565  0.65304778]
#  [-1.16286263  1.44302493]]

# %%
# Ejercicio practico Estandarización y Normalización

# load and summarize the sonar dataset
from pandas import read_csv
from pandas.plotting import scatter_matrix
from matplotlib import pyplot
# Load dataset
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/sonar.csv"
dataset = read_csv(url, header=None)
# summarize the shape of the dataset
print(dataset.shape)
# summarize each variable
print(dataset.describe())
# histograms of the variables
dataset.hist()
pyplot.show()
# Out:
# (208, 61)
#                0           1           2           3           4           5   \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                6           7           8           9   ...          50  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean     0.121747    0.134799    0.178003    0.208259  ...    0.016069
# ...

# %%
# Implementación primer algoritmo K-Vecinos mas cercanos

# evaluate knn on the raw sonar dataset
from numpy import mean
from numpy import std
from pandas import read_csv
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelEncoder
from matplotlib import pyplot
# load dataset
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/sonar.csv"
dataset = read_csv(url, header=None)
data = dataset.values
# separate into input and output columns
X, y = data[:, :-1], data[:, -1]
# ensure inputs are floats and output is an integer label
X = X.astype('float32')
y = LabelEncoder().fit_transform(y.astype('str'))
# define and configure the model
model = KNeighborsClassifier()
# evaluate the model
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# report model performance
print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# Out:
# Accuracy: 0.797 (0.073)

# %%
# Calculo de la distancia Euclideana
import numpy as np
from scipy.spatial import distance

a = np.array([0.4       , 0.3220339 , 0.46268657, 0.58895706, 0.11688312])
b = np.array([0.33333333, 0.47457627, 0.50746269, 0.66257669, 0.1038961 ])


print(distance.euclidean(a,b))
# Out:
# 0.1879016579654834

# %%
c= np.array([2,3,4,6,8])
d = np.array([3,1,3,6,4])
print("potencia de un arreglo : ", c**2)
print("Producto de arreglos", c*d)
# Out:
# potencia de un arreglo :  [ 4  9 16 36 64]
# Producto de arreglos [ 6  3 12 36 32]

# %%
m = np.array([[2,3,4,6,8],
             [3,1,3,6,4],
             [10,2,1,2,4],
             [5,5,4,2,4],
             [8,7,1,1,1]])

# %%
# Generar el vector de pesos
import random
import numpy as np

w = np.random.rand(3)
s  = np.sum(w)

wf = w/s


print("Array: ", w)
print("Suma elemntos Array: ", s)
print("Pesos Ponderados Finales: ", wf)
# Out:
# Array:  [0.1711585  0.01740633 0.75294244]
# Suma elemntos Array:  0.9415072681433803
# Pesos Ponderados Finales:  [0.18179201 0.01848773 0.79972026]

# %%
ri = ((d-c)**2)
rii = ri * wf
dE = np.sqrt(np.sum(rii))
print(dE)
# Out:
# 1.0273573794101034

# %%
def generarVectorPesos(dim):
    w = np.random.rand(dim)
    s  = np.sum(w)
    wf = w/s

    return wf

# %%
wi = generarVectorPesos(5)
print(wi)
# Out:
# [0.34515093 0.20699057 0.1160161  0.08256045 0.24928196]

# %%
m = np.array([[2,3,4,6,8],
             [3,1,3,6,4],
             [10,2,1,2,4],
             [5,5,4,2,4],
             [8,7,1,1,1]])

# %%
# Vector Distancias Euclideanas Ponderadas
dEP = []
y_pred = []
for i in range(len(m)):
    # Saco elemento elemento del dataset
    vrf = m[i]
    print("Elemento: ", vrf) 

    for j in range(len(m)):
        if i == j:
            dEP.append(1000)
            print("Cumplio Criterio")
        
        else:
            print("V1: ", m[j])
            print("v2: ", vrf)
            ri = ((m[j] - vrf)**2)* wi
            dE = np.sqrt(np.sum(ri))
            dEP.append(dE)
    
    print(f"iteracion {i}, distancias ponderadas {dEP}")
    # Calculo del y_pred
    minDep = dEP.index(min(dEP))
    dEP = []
# Out:
# Elemento:  [2 3 4 6 8]
# Cumplio Criterio
# V1:  [3 1 3 6 4]
# v2:  [2 3 4 6 8]
# V1:  [10  2  1  2  4]
# v2:  [2 3 4 6 8]
# V1:  [5 5 4 2 4]
# v2:  [2 3 4 6 8]
# V1:  [8 7 1 1 1]
# v2:  [2 3 4 6 8]
# iteracion 0, distancias ponderadas [1000, 2.29731160535182, 5.352595002319863, 3.0403616752006277, 5.573172747218353]
# Elemento:  [3 1 3 6 4]
# V1:  [2 3 4 6 8]
# v2:  [3 1 3 6 4]
# Cumplio Criterio
# V1:  [10  2  1  2  4]
# v2:  [3 1 3 6 4]
# V1:  [5 5 4 2 4]
# v2:  [3 1 3 6 4]
# V1:  [8 7 1 1 1]
# v2:  [3 1 3 6 4]
# iteracion 1, distancias ponderadas [2.29731160535182, 1000, 4.347921061558656, 2.4757697992645817, 4.566404153343751]
# Elemento:  [10  2  1  2  4]
# V1:  [2 3 4 6 8]
# v2:  [10  2  1  2  4]
# V1:  [3 1 3 6 4]
# v2:  [10  2  1  2  4]
# Cumplio Criterio
# V1:  [5 5 4 2 4]
# v2:  [10  2  1  2  4]
# V1:  [8 7 1 1 1]
# v2:  [10  2  1  2  4]
# iteracion 2, distancias ponderadas [5.352595002319863, 4.347921061558656, 1000, 3.396444195227519, 2.9801788530765383]
# ...

# %%
l = [1000, 1.7280777210190974, 4.816928817651555, 2.535836288479205, 4.248300376990154]

# %%
l.index(min(l))
# Out:
# 1

# %%
# ordenar lso elemnetos de un array

import numpy as np

array = np.array([[1, 1, 2], [0, 0, 1], [1, 2, 3]])
print("Array before sorting\n", array)

array[array[:, 1].argsort()]
print("Array after sorting\n", array)
# Out:
# Array before sorting
#  [[1 1 2]
#  [0 0 1]
#  [1 2 3]]
# Array after sorting
#  [[1 1 2]
#  [0 0 1]
#  [1 2 3]]

# %%
array[:, 1].argsort()
# Out:
# array([1, 0, 2], dtype=int64)
